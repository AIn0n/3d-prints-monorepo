# %%
from jupyterscad import view

from omegaconf import OmegaConf

from configuration import schema
from common import generate_key

# %%
yaml_config = OmegaConf.load("default.conf.yaml")
conf = OmegaConf.merge(schema, yaml_config)
conf
# Out:
# {'u_dist': 19.05, 'white_key_len': 1.75, 'white_key_width': 1.25, 'mount_plate_width': 1.25, 'mount_u': 14.0, 'keycap_u': 18.0, 'keycap_height_mm': 1.0, 'keycap_rounding_corner_mm': 2.0, 'output_dir': PosixPath('build')}

# %%
white_key = generate_key(conf.white_key_width, conf.white_key_len, conf)

# %%
view(white_key)
# Out:
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.7, position=(3.0, 5.0,…

# %%
conf.output_dir.mkdir(parents=True, exist_ok=True)

white_key.save_as_stl(conf.output_dir / "white_keycap.stl")
# Out:
# '/home/szymon/inne/git/3d-prints-monorepo/midi_keyboard/build/white_keycap.stl'
