# %%
from jupyterscad import view

from omegaconf import OmegaConf

from configuration import load_config
from mx_keys import generate_key

# %%
conf = load_config()

# %%
black_key = generate_key(conf.black_key_dims.width, conf.black_key_dims.length, conf)

# %%
view(black_key)

# %%
conf.output_dir.mkdir(parents=True, exist_ok=True)

black_key.save_as_stl(conf.output_dir / "black_keycap.stl")
